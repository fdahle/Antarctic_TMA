# %%
# %load_ext autoreload
# %autoreload 2

# %%
mode = "random"  # can be 'random' or 'id'
image_id = ""

# %%
import src.base.connect_to_database as ctd
import src.text.find_height as fh

# create connection to database
conn = ctd.establish_connection()

max_tries = 100

# if random mode, get random image id
if mode == "random":
    sql_string = "SELECT image_id FROM images_extracted " \
                 "WHERE text_content is NOT NULL " \
                 f"ORDER BY RANDOM() LIMIT {max_tries}"
    image_ids = ctd.execute_sql(sql_string, conn)['image_id']

for image_id in image_ids:

    # get the text content
    sql_string = f"SELECT text_content FROM images_extracted " \
                 f"WHERE image_id='{image_id}'"
    text_content = ctd.execute_sql(sql_string, conn)['text_content'].iloc[0]

    print(f"Find height for {image_id} with following text:")
    print(text_content)

    height = fh.find_height(text_content)
    print("Height:", height)
    print("")

    if height is not None:
        break
# Out:
# Find height for CA180032V0078 with following text:
# PALMER LANDT M A 18CO 4NOV68 F32M1126 00078;8;18 6 16 8 14 10 CAL.FL 51.982mm 0236 KC-1 LENSSER.NO 585 SER. BU-31 NO. MISSIONM;;22 20
# Height: None
#
# Find height for CA214732V0005 with following text:
# F32 USNGS T 11 17 122463 PENINSULA TMA 2147 0005;5;F045 T-II NS SE.NO S2294 Ro 54-655 12-246 FE-3;22 4
# Height: None
#
# Find height for CA164231L0098 with following text:
# NS SER. NO II-1;F31 R
# Height: None
#
# Find height for CA180633R0115 with following text:
# PALMER LAND TMA 1806 F33M313019NOV66;0115;Eg 19-66 EO M NOL 54-653 449 SSER.NO KC-1 719mm AL.F.L
# Height: None
#
# Find height for CA135232V0209 with following text:
# KODAK;9/26/64 5000 O153.04MM ANT PENTMA1352;2% 3 5 6 L.F.L. 06mm 249 T-II SER.NO. 2613 54.557 ANVERS I.S. 6-64 K -32
# Height: None
#
# Find height for CA181632V0047 with following text:
# PALMER LAND TMA 1816 F32M219116NOV66;8;0047;22 2 4 20 6 18 8. 16 14 10 CAL.F.L 51.982mm 05 KC-1 LENSSER.NO 585 SER.BU-31 NO. SSVOMA RT7OO 1-16-66 F32
# Height: None
#
# Find height for CA207433R0156 with following text:
# KODAKSAFET;12/10/67 PALMER TMA2074;54367
# Height: None
#
# Find height for CA181531L0044 with following text:
# ;F31M11254NOV66 PALMER LANDTMA 1815;0044;8 14 1210 CAL.FL 51.776mm KC-I NSSER.NO. 461 ER. 54-648 10
# Height: None
#
# Find height for CA172333R0165 with following text:
# KODAKAEROGRAPHICSAFETYFILN;KODAKAEROGRAPHICSAFETYFILN;2.54-653 F33 ANL6Z;11619 KC-I SSER.NO 449;6S ECO0 151.717MM KOLERT172;KODAKAEROGR;165
# Height: None
#
# Find height for CA196633R0030 with following text:
# 12 L.F.L 734mm 0.42 KC-I SSER.NO 394 54-557;151.734MM TMA1988 USGS
# Height: None
#
# Find height for CA174832V0287 with following text:
# 4-557 64 SER.NO 1-0;KODAKAEROGR
# Height: None
#
# Find height for CA173233R0173 with following text:
# KODAK AEROGRAPHIC SAFETYFIL!;9,6 KC-I NS SER.NO 223 ER. 52-015 10 11-005 33 TAN66Z;KODAKAEROGRAPHICSAFETYFILM 1A-A
# Height: None
#
# Find height for CA215132V0294 with following text:
# PENINSUI.A TMA 2151 0294;5;85 -I1 SER.NO. 2294 54-655 2-e/ F-32
# Height: None
#
# Find height for CA213633R0391 with following text:
# KODAKSAFETYFI;PALMER LAND TMA 2136 0391;8 C 12 L.F.L. 46mm;265 T-II SER.NO 4224 54658 ot-0l SORTE;24
# Height: None
#
# Find height for CA212333R0011 with following text:
# KODAKSAFFT;F33 U8N GS M 4 11 1i 23 89 PALMER FILL TMA 2123 0011;46S8 ERZAN 00;10:212 T-II NS SER.NO RF4224;KODAKSAFFTY;24 2 22 4 0 6 8 14 12 AL.F.L 3.46mm
# Height: None
#
# Find height for CA213831L0189 with following text:
# 0189.;F31USNGS T 1014 122363 PENINSULA TMA 2138;10 .F.L. ww.968;!2 A-14 R.NO. 961 54-284 23-21
# Height: None
#
# Find height for CA182733R0051 with following text:
# MA1827 F33M5115I8DEC66 PALMER LAND;00051;3 R.NO
# Height: None
#
# Find height for CA214333R0354 with following text:
# PENINSULA TMA 2143 0354;10 F.L. 6mm 30 -11 ER.NO 1224 4658 12-2 SORTE yoissil;4 2
# Height: None
#
# Find height for CA168033R0043 with following text:
# KODA;KODAK AERECON SAFETY FILA;KODAK AERECON SAFETY FILA;043 F33R-1-1 8/1;R.54-653 449 NSSER.NO KC-1 1.719mm AL.F.L 3
# Height: None
#
# Find height for CA185133R0170 with following text:
# 34mm F.L OI;-557 4 ER.NO. -;WIE 191
# Height: None
#
# Find height for CA512531L0051 with following text:
# 52-3;1-24-47 THWAITES;10,000;GLACIER;152.8 TMA 5i25 R-8;;F-31;50;F-31;TM 5i25;
# Height: None
#
# Find height for CA182133R0191 with following text:
# PALMER LANDTMA 182I F33 M211816NJVC6;0191;3 AL.F.L 719mm 20 KC-I SSER.NO. 449 R.54-653
# Height: None
#
# Find height for CA214032V0370 with following text:
# PENINSULA TMA 2140 0370;NO. 94 655;2 4 6 8
# Height: None
#
# Find height for CA215731L0016 with following text:
# F31 USN GS T 12 15A f 27 38 PENINSULA TMA 2157 0016;SONFEET 5;14 10 CAL.F.L. 4.396mm CA-14 R.NO. RF931 SER 54-284 NO. 12-27 1E-
# Height: None
#
# Find height for CA184532V0225 with following text:
# 225 TMA 1845 VERT 12/27/1966;5;ER. BU-93 M a3-66;6 8 1410 AL.F.L 2.004mm;25:2 NSSER.NO. 539;USGS;24 22
# Height: None
#
# Find height for CA180131L0141 with following text:
# 141 PALMER LANDT MA 18OI F31M1i27 4NV68;2 2;ALFL 11 8 9;54-648 461 SSER.NO. KC-I
# Height: None
#
# Find height for CA182731L0105 with following text:
# LENS 4 SER NO;CA 151.;18 16;TMA 1827PALMER LAND F31M51153DEC6;0105
# Height: None
#
# Find height for CA172231L0084 with following text:
# KODAKAFROGRAPHICSAFETYFILMIA-A;1814 KC-1 SER.NO. 61 54-648;
# Height: None
#
# Find height for CA174033R0018 with following text:
# 0028 KC-1 ENS SER.NO 223 SER. 52-015 NO;5;-147-1/37/60 23300 151.3
# Height: 23300
