# %%
fld = "/data_1/ATM/data_1/sfm/projects/src_test2/stats/"
txt_file = "2024_03_04_00_16_21_Tapas_raw.txt"

# %%
f = open(fld + txt_file, 'r')
raw_output = f.read()

# %%
import re

def extract_stats(raw_output):
    stats = {
        "general_info": {"total_images": 0, "matches": 0},
        "calibration": {},
        "epochs": [],
        "warnings": {"total_warnings": 0, "types": []}
    }

    lines = raw_output.split("\n")

    current_epoch = None
    for line in lines:

        # count number of images
        if '"OIS.*tif":' in line:
            stats["general_info"]["total_images"] = int(re.search(r'(\d+) matches', line).group(1))

        # get calibration info
        if "MdPppppF=" in line:
            stats["calibration"] = {
                "MdPppppF": float(re.search(r'MdPppppF= (\d+\.\d+)', line).group(1)),
                "SFE": float(re.search(r'SFE=(-?\d+(?:\.\d+)?)', line).group(1)),
                "FocMm": float(re.search(r'FocMm(\d+\.\d+)', line).group(1)),
                "XSZ": [int(x) for x in re.findall(r'XSZ=\[(\d+),(\d+)\]', line)[0]],
            }

        # get summary of an iteration
        if "--- End Iter" in line:
            match = re.search(r'--- End Iter (\d+) STEP (\d+)', line)
            if match:
                current_epoch = {"epoch": f"{match.group(1)}-{match.group(2)}", "image_processing": [], "statistical_summary": {}, "epoch_stats": {}}
                stats["epochs"].append(current_epoch)

        # get properties of images
        if "RES:" in line and current_epoch is not None:
            image_stats, image_name = parse_image_stats(line)
            if image_name:  # Ensure an image name was actually found
                current_epoch["image_processing"].append({"image": image_name, **image_stats})

        if "Stat on type of point" in line and current_epoch:
            current_epoch["statistical_summary"] = {}

        if "Perc=" in line and current_epoch:
            match = re.search(r'Perc=(\d+\.\d+)% ;  Nb=(\d+) for (\w+)', line)
            if match:
                current_epoch["statistical_summary"][match.group(3)] = {
                    "percentage": float(match.group(1)),
                    "number": int(match.group(2)),
                }
        if "| |" in line and current_epoch:
            key, value = line.split(";;")[0].strip("| | ").split(" = ")
            current_epoch["epoch_stats"][key] = float(value)
    print(stats)

    return stats


def parse_image_stats(line):
    # Split the line by spaces, but first remove the image name part to avoid confusion
    image_name_match = re.search(r'RES:\[(.+?)\]\[C\]', line)
    if not image_name_match:
        return {}, ""
    image_name = image_name_match.group(1)

    # Remove the part of the line before the stats start
    stats_part = line.split(" ", 2)[-1]  # Gets the part after the image name and [C]

    # Now, split the stats part into individual stats assuming key-value pairs
    parts = stats_part.split()
    stats_dict = {}
    i = 0
    while i < len(parts) - 1:  # Ensure there's always a pair to process
        key = parts[i].rstrip(':')  # Clean up the key
        try:
            # Attempt to convert the next part to a float
            value = float(parts[i + 1])
            stats_dict[key] = value
            i += 2  # Move past this key-value pair
        except ValueError:
            # If conversion fails, it's likely not a numeric value; skip this pair
            i += 1  # Just move to the next part, treating it as a potential key

    return stats_dict, image_name

# %%
import json
jsons_stats = extract_stats(raw_output)
print(json.dumps(jsons_stats, indent=4))
# Out:
# {'general_info': {'total_images': 9, 'matches': 0}, 'calibration': {'MdPppppF': 1.81514, 'SFE': -1.0, 'FocMm': 152.274, 'XSZ': [8800, 8800]}, 'epochs': [{'epoch': '0-0', 'image_processing': [{'image': 'OIS-Reech_CA214732V0027.tif', 'Nn': 0.367647, 'Of': 544.0, 'Mul': 208.0, 'Mul-NN': 0.0, 'Time': 0.00979686}, {'image': 'OIS-Reech_CA214732V0028.tif', 'Nn': 1.08696, 'Of': 828.0, 'Mul': 414.0, 'Mul-NN': 0.0, 'Time': 0.01389}, {'image': 'OIS-Reech_CA214732V0029.tif', 'Nn': 0.938967, 'Of': 852.0, 'Mul': 674.0, 'Mul-NN': 0.0, 'Time': 0.012727}, {'image': 'OIS-Reech_CA214732V0030.tif', 'Nn': 1.78571, 'Of': 840.0, 'Mul': 663.0, 'Mul-NN': 9.0, 'Time': 0.0130901}, {'image': 'OIS-Reech_CA214732V0031.tif', 'Nn': 17.7976, 'Of': 899.0, 'Mul': 718.0, 'Mul-NN': 123.0, 'Time': 0.0132339}, {'image': 'OIS-Reech_CA214732V0032.tif', 'Nn': 39.5266, 'Of': 845.0, 'Mul': 615.0, 'Mul-NN': 272.0, 'Time': 0.014185}, {'image': 'OIS-Reech_CA214732V0033.tif', 'Nn': 72.1779, 'Of': 877.0, 'Mul': 692.0, 'Mul-NN': 527.0, 'Time': 0.018275}, {'image': 'OIS-Reech_CA214732V0034.tif', 'Nn': 98.4561, 'Of': 842.0, 'Mul': 423.0, 'Mul-NN': 416.0, 'Time': 0.0217209}, {'image': 'OIS-Reech_CA214732V0035.tif', 'Nn': 98.505, 'Of': 602.0, 'Mul': 268.0, 'Mul-NN': 264.0, 'Time': 0.0153439}], 'statistical_summary': {'Ok': {'percentage': 36.2323, 'number': 2583}, 'PdsResNull': {'percentage': 29.7237, 'number': 2119}, 'BSurH': {'percentage': 10.0014, 'number': 713}, 'VisibIm': {'percentage': 24.0426, 'number': 1714}}, 'epoch_stats': {}}, {'epoch': '1-0', 'image_processing': [{'image': 'OIS-Reech_CA214732V0027.tif', 'Nn': 0.0, 'Of': 544.0, 'Mul': 208.0, 'Mul-NN': 0.0, 'Time': 0.0209999}, {'image': 'OIS-Reech_CA214732V0028.tif', 'Nn': 1.20773, 'Of': 828.0, 'Mul': 414.0, 'Mul-NN': 0.0, 'Time': 0.0241899}, {'image': 'OIS-Reech_CA214732V0029.tif', 'Nn': 1.17371, 'Of': 852.0, 'Mul': 674.0, 'Mul-NN': 0.0, 'Time': 0.0193832}, {'image': 'OIS-Reech_CA214732V0030.tif', 'Nn': 0.0, 'Of': 840.0, 'Mul': 663.0, 'Mul-NN': 0.0, 'Time': 0.0169241}, {'image': 'OIS-Reech_CA214732V0031.tif', 'Nn': 18.6874, 'Of': 899.0, 'Mul': 718.0, 'Mul-NN': 127.0, 'Time': 0.015662}, {'image': 'OIS-Reech_CA214732V0032.tif', 'Nn': 42.0118, 'Of': 845.0, 'Mul': 615.0, 'Mul-NN': 276.0, 'Time': 0.0148721}, {'image': 'OIS-Reech_CA214732V0033.tif', 'Nn': 74.8005, 'Of': 877.0, 'Mul': 692.0, 'Mul-NN': 539.0, 'Time': 0.0188811}, {'image': 'OIS-Reech_CA214732V0034.tif', 'Nn': 98.4561, 'Of': 842.0, 'Mul': 423.0, 'Mul-NN': 415.0, 'Time': 0.021939}, {'image': 'OIS-Reech_CA214732V0035.tif', 'Nn': 98.3389, 'Of': 602.0, 'Mul': 268.0, 'Mul-NN': 263.0, 'Time': 0.0152838}], 'statistical_summary': {'Ok': {'percentage': 36.7513, 'number': 2620}, 'PdsResNull': {'percentage': 3.91359, 'number': 279}, 'BSurH': {'percentage': 8.92131, 'number': 636}, 'Behind': {'percentage': 0.378735, 'number': 27}, 'VisibIm': {'percentage': 50.0351, 'number': 3567}}, 'epoch_stats': {}}, {'epoch': '2-0', 'image_processing': [{'image': 'OIS-Reech_CA214732V0027.tif', 'Nn': 0.0, 'Of': 544.0, 'Mul': 208.0, 'Mul-NN': 0.0, 'Time': 0.00746489}, {'image': 'OIS-Reech_CA214732V0028.tif', 'Nn': 1.20773, 'Of': 828.0, 'Mul': 414.0, 'Mul-NN': 0.0, 'Time': 0.011585}, {'image': 'OIS-Reech_CA214732V0029.tif', 'Nn': 1.17371, 'Of': 852.0, 'Mul': 674.0, 'Mul-NN': 0.0, 'Time': 0.0113518}, {'image': 'OIS-Reech_CA214732V0030.tif', 'Nn': 0.0, 'Of': 840.0, 'Mul': 663.0, 'Mul-NN': 0.0, 'Time': 0.0116999}, {'image': 'OIS-Reech_CA214732V0031.tif', 'Nn': 10.1224, 'Of': 899.0, 'Mul': 718.0, 'Mul-NN': 67.0, 'Time': 0.01091}, {'image': 'OIS-Reech_CA214732V0032.tif', 'Nn': 32.426, 'Of': 845.0, 'Mul': 615.0, 'Mul-NN': 223.0, 'Time': 0.01195}, {'image': 'OIS-Reech_CA214732V0033.tif', 'Nn': 67.3888, 'Of': 877.0, 'Mul': 692.0, 'Mul-NN': 487.0, 'Time': 0.0168509}, {'image': 'OIS-Reech_CA214732V0034.tif', 'Nn': 99.0499, 'Of': 842.0, 'Mul': 423.0, 'Mul-NN': 420.0, 'Time': 0.0216799}, {'image': 'OIS-Reech_CA214732V0035.tif', 'Nn': 98.8372, 'Of': 602.0, 'Mul': 268.0, 'Mul-NN': 266.0, 'Time': 0.0152719 ...
# {
#     "general_info": {
#         "total_images": 9,
#         "matches": 0
#     },
#     "calibration": {
#         "MdPppppF": 1.81514,
#         "SFE": -1.0,
#         "FocMm": 152.274,
#         "XSZ": [
#             8800,
#             8800
#         ]
#     },
#     "epochs": [
#         {
#             "epoch": "0-0",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.367647,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00979686
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 1.08696,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.01389
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.938967,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.012727
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 1.78571,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 9.0,
#                     "Time": 0.0130901
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 17.7976,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 123.0,
#                     "Time": 0.0132339
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 39.5266,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 272.0,
#                     "Time": 0.014185
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 72.1779,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 527.0,
#                     "Time": 0.018275
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 98.4561,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 416.0,
#                     "Time": 0.0217209
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 98.505,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 264.0,
#                     "Time": 0.0153439
#                 }
#             ],
#             "statistical_summary": {
#                 "Ok": {
#                     "percentage": 36.2323,
#                     "number": 2583
#                 },
#                 "PdsResNull": {
#                     "percentage": 29.7237,
#                     "number": 2119
#                 },
#                 "BSurH": {
#                     "percentage": 10.0014,
#                     "number": 713
#                 },
#                 "VisibIm": {
#                     "percentage": 24.0426,
#                     "number": 1714
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "1-0",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0209999
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 1.20773,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0241899
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 1.17371,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0193832
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0169241
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 18.6874,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 127.0,
#                     "Time": 0.015662
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 42.0118,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 276.0,
#                     "Time": 0.0148721
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 74.8005,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 539.0,
#                     "Time": 0.0188811
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 98.4561,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 415.0,
#                     "Time": 0.021939
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 98.3389,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 263.0,
#                     "Time": 0.0152838
#                 }
#             ],
#             "statistical_summary": {
#                 "Ok": {
#                     "percentage": 36.7513,
#                     "number": 2620
#                 },
#                 "PdsResNull": {
#                     "percentage": 3.91359,
#                     "number": 279
#                 },
#                 "BSurH": {
#                     "percentage": 8.92131,
#                     "number": 636
#                 },
#                 "Behind": {
#                     "percentage": 0.378735,
#                     "number": 27
#                 },
#                 "VisibIm": {
#                     "percentage": 50.0351,
#                     "number": 3567
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "2-0",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00746489
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 1.20773,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.011585
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 1.17371,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0113518
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0116999
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 10.1224,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 67.0,
#                     "Time": 0.01091
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 32.426,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 223.0,
#                     "Time": 0.01195
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 67.3888,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 487.0,
#                     "Time": 0.0168509
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 99.0499,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 420.0,
#                     "Time": 0.0216799
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 98.8372,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 266.0,
#                     "Time": 0.0152719
#                 }
#             ],
#             "statistical_summary": {
#                 "Ok": {
#                     "percentage": 33.7354,
#                     "number": 2405
#                 },
#                 "PdsResNull": {
#                     "percentage": 3.1421,
#                     "number": 224
#                 },
#                 "BSurH": {
#                     "percentage": 12.2738,
#                     "number": 875
#                 },
#                 "Behind": {
#                     "percentage": 0.336653,
#                     "number": 24
#                 },
#                 "VisibIm": {
#                     "percentage": 50.512,
#                     "number": 3601
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "3-0",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.021513
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 0.483092,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.024689
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.469484,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0192559
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0169649
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 17.3526,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 121.0,
#                     "Time": 0.0151119
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 40.1183,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 273.0,
#                     "Time": 0.0145149
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 73.7742,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 537.0,
#                     "Time": 0.0186501
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 98.6936,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 417.0,
#                     "Time": 0.0214579
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 98.505,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 264.0,
#                     "Time": 0.015135
#                 }
#             ],
#             "statistical_summary": {
#                 "Ok": {
#                     "percentage": 36.106,
#                     "number": 2574
#                 },
#                 "PdsResNull": {
#                     "percentage": 3.56291,
#                     "number": 254
#                 },
#                 "BSurH": {
#                     "percentage": 9.56656,
#                     "number": 682
#                 },
#                 "Behind": {
#                     "percentage": 0.336653,
#                     "number": 24
#                 },
#                 "VisibIm": {
#                     "percentage": 50.4278,
#                     "number": 3595
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "4-0",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0214531
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 0.362319,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0240259
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.352113,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0179501
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.015794
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 38.2647,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 260.0,
#                     "Time": 0.0194168
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 69.3491,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 407.0,
#                     "Time": 0.019871
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 64.1961,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 408.0,
#                     "Time": 0.021281
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 41.4489,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 151.0,
#                     "Time": 0.0182519
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 16.6113,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0118232
#                 }
#             ],
#             "statistical_summary": {
#                 "Ok": {
#                     "percentage": 27.325,
#                     "number": 1948
#                 },
#                 "PdsResNull": {
#                     "percentage": 26.792,
#                     "number": 1910
#                 },
#                 "BSurH": {
#                     "percentage": 0.448871,
#                     "number": 32
#                 },
#                 "Behind": {
#                     "percentage": 3.15612,
#                     "number": 225
#                 },
#                 "VisibIm": {
#                     "percentage": 42.278,
#                     "number": 3014
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "5-0",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.020283
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 0.0,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.023407
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.0,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0183468
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.016536
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 39.4883,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 270.0,
#                     "Time": 0.02016
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 48.4024,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 268.0,
#                     "Time": 0.018028
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 41.3911,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 269.0,
#                     "Time": 0.01788
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 0.0,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0127881
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 0.0,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00900388
#                 }
#             ],
#             "statistical_summary": {
#                 "Ok": {
#                     "percentage": 15.8087,
#                     "number": 1127
#                 },
#                 "PdsResNull": {
#                     "percentage": 2.35657,
#                     "number": 168
#                 },
#                 "Behind": {
#                     "percentage": 3.12807,
#                     "number": 223
#                 },
#                 "VisibIm": {
#                     "percentage": 78.7067,
#                     "number": 5611
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "6-0",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.021209
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 0.0,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.023741
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.0,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0188091
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.01704
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 39.4883,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 270.0,
#                     "Time": 0.0209231
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 48.4024,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 268.0,
#                     "Time": 0.018306
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 41.3911,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 269.0,
#                     "Time": 0.017782
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 0.0,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.012543
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 0.0,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00903702
#                 }
#             ],
#             "statistical_summary": {
#                 "Ok": {
#                     "percentage": 15.8087,
#                     "number": 1127
#                 },
#                 "PdsResNull": {
#                     "percentage": 2.35657,
#                     "number": 168
#                 },
#                 "Behind": {
#                     "percentage": 3.12807,
#                     "number": 223
#                 },
#                 "VisibIm": {
#                     "percentage": 78.7067,
#                     "number": 5611
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "7-0",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00750804
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 0.0,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0113511
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.0,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0109248
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.011672
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 39.4883,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 270.0,
#                     "Time": 0.0174901
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 48.4024,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 268.0,
#                     "Time": 0.0176392
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 41.3911,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 269.0,
#                     "Time": 0.0177891
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 0.0,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.012445
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 0.0,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00892091
#                 }
#             ],
#             "statistical_summary": {
#                 "Ok": {
#                     "percentage": 15.8087,
#                     "number": 1127
#                 },
#                 "PdsResNull": {
#                     "percentage": 2.35657,
#                     "number": 168
#                 },
#                 "Behind": {
#                     "percentage": 3.12807,
#                     "number": 223
#                 },
#                 "VisibIm": {
#                     "percentage": 78.7067,
#                     "number": 5611
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "8-0",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0151131
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 0.0,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0202589
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.0,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.016808
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0150859
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 39.4883,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 270.0,
#                     "Time": 0.018806
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 48.4024,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 268.0,
#                     "Time": 0.0176601
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 41.3911,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 269.0,
#                     "Time": 0.0178311
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 0.0,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.012758
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 0.0,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00894904
#                 }
#             ],
#             "statistical_summary": {
#                 "Ok": {
#                     "percentage": 15.8087,
#                     "number": 1127
#                 },
#                 "PdsResNull": {
#                     "percentage": 2.35657,
#                     "number": 168
#                 },
#                 "Behind": {
#                     "percentage": 3.12807,
#                     "number": 223
#                 },
#                 "VisibIm": {
#                     "percentage": 78.7067,
#                     "number": 5611
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "9-0",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.014735
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 0.0,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.021816
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.0,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0170341
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.015394
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 39.1546,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 267.0,
#                     "Time": 0.0205121
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 48.0473,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 265.0,
#                     "Time": 0.0176079
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 41.049,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 266.0,
#                     "Time": 0.0179338
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 0.0,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0125899
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 0.0,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00892711
#                 }
#             ],
#             "statistical_summary": {
#                 "Ok": {
#                     "percentage": 15.6824,
#                     "number": 1118
#                 },
#                 "PdsResNull": {
#                     "percentage": 2.48282,
#                     "number": 177
#                 },
#                 "Behind": {
#                     "percentage": 3.12807,
#                     "number": 223
#                 },
#                 "VisibIm": {
#                     "percentage": 78.7067,
#                     "number": 5611
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "10-0",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.012764
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 0.0,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0177629
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.0,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0144219
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0133801
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 32.0356,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 267.0,
#                     "Time": 0.0187819
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 40.4734,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 265.0,
#                     "Time": 0.017153
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 41.049,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 266.0,
#                     "Time": 0.0178349
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 0.0,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.012536
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 0.0,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0090909
#                 }
#             ],
#             "statistical_summary": {
#                 "Ok": {
#                     "percentage": 13.8869,
#                     "number": 990
#                 },
#                 "PdsResNull": {
#                     "percentage": 4.2783,
#                     "number": 305
#                 },
#                 "Behind": {
#                     "percentage": 3.12807,
#                     "number": 223
#                 },
#                 "VisibIm": {
#                     "percentage": 78.7067,
#                     "number": 5611
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "11-0",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00755501
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 0.0,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.011703
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.0,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0111592
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0117619
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 0.444939,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.014837
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 0.0,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0147729
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 0.4561,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0172861
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 0.0,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.012742
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 0.0,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00913811
#                 }
#             ],
#             "statistical_summary": {
#                 "Ok": {
#                     "percentage": 0.112218,
#                     "number": 8
#                 },
#                 "PdsResNull": {
#                     "percentage": 18.053,
#                     "number": 1287
#                 },
#                 "Behind": {
#                     "percentage": 3.12807,
#                     "number": 223
#                 },
#                 "VisibIm": {
#                     "percentage": 78.7067,
#                     "number": 5611
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "0-1",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.007689
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 0.0,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0116589
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.0,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0111969
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0119669
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 0.0,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0137119
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 0.0,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0133309
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 0.0,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0135319
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 0.0,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0128891
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 0.0,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00897694
#                 }
#             ],
#             "statistical_summary": {
#                 "PdsResNull": {
#                     "percentage": 4.18011,
#                     "number": 298
#                 },
#                 "Behind": {
#                     "percentage": 3.12807,
#                     "number": 223
#                 },
#                 "VisibIm": {
#                     "percentage": 92.6918,
#                     "number": 6608
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "1-1",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0076828
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 0.0,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.011483
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.0,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0111091
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0117531
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 0.0,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0135732
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 0.0,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0131109
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 0.0,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0131989
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 0.0,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0134459
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 0.0,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00994086
#                 }
#             ],
#             "statistical_summary": {
#                 "PdsResNull": {
#                     "percentage": 4.18011,
#                     "number": 298
#                 },
#                 "Behind": {
#                     "percentage": 3.12807,
#                     "number": 223
#                 },
#                 "VisibIm": {
#                     "percentage": 92.6918,
#                     "number": 6608
#                 }
#             },
# ...
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.012732
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 0.0,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.009866
#                 }
#             ],
#             "statistical_summary": {
#                 "PdsResNull": {
#                     "percentage": 4.18011,
#                     "number": 298
#                 },
#                 "Behind": {
#                     "percentage": 3.12807,
#                     "number": 223
#                 },
#                 "VisibIm": {
#                     "percentage": 92.6918,
#                     "number": 6608
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "0-2",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00928712
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 0.0,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.01232
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.0,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.012265
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0116701
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 0.0,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0133951
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 0.0,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0130889
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 0.0,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.013248
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 0.0,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0124712
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 0.0,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00899005
#                 }
#             ],
#             "statistical_summary": {
#                 "PdsResNull": {
#                     "percentage": 4.18011,
#                     "number": 298
#                 },
#                 "Behind": {
#                     "percentage": 3.12807,
#                     "number": 223
#                 },
#                 "VisibIm": {
#                     "percentage": 92.6918,
#                     "number": 6608
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "1-2",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00784087
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 0.0,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0112419
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.0,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0108531
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.011555
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 0.0,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.013166
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 0.0,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0141909
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 0.0,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0133419
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 0.0,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0123341
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 0.0,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00910497
#                 }
#             ],
#             "statistical_summary": {
#                 "PdsResNull": {
#                     "percentage": 4.18011,
#                     "number": 298
#                 },
#                 "Behind": {
#                     "percentage": 3.12807,
#                     "number": 223
#                 },
#                 "VisibIm": {
#                     "percentage": 92.6918,
#                     "number": 6608
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "0-3",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.010237
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 0.0,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0136709
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.0,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0118511
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.012229
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 0.0,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.013495
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 0.0,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0132179
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 0.0,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0134439
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 0.0,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0126112
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 0.0,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0108671
#                 }
#             ],
#             "statistical_summary": {
#                 "PdsResNull": {
#                     "percentage": 4.18011,
#                     "number": 298
#                 },
#                 "Behind": {
#                     "percentage": 3.12807,
#                     "number": 223
#                 },
#                 "VisibIm": {
#                     "percentage": 92.6918,
#                     "number": 6608
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "1-3",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.013567
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 0.0,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0175831
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.0,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0146301
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0135272
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 0.0,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0137789
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 0.0,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0131578
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 0.0,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0134521
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 0.0,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0127139
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 0.0,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00891399
#                 }
#             ],
#             "statistical_summary": {
#                 "PdsResNull": {
#                     "percentage": 4.18011,
#                     "number": 298
#                 },
#                 "Behind": {
#                     "percentage": 3.12807,
#                     "number": 223
#                 },
#                 "VisibIm": {
#                     "percentage": 92.6918,
#                     "number": 6608
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "2-3",
#             "image_processing": [
#                 {
#                     "image": "OIS-Reech_CA214732V0027.tif",
#                     "Nn": 0.0,
#                     "Of": 544.0,
#                     "Mul": 208.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0173488
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0028.tif",
#                     "Nn": 0.0,
#                     "Of": 828.0,
#                     "Mul": 414.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.022193
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0029.tif",
#                     "Nn": 0.0,
#                     "Of": 852.0,
#                     "Mul": 674.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0176229
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0030.tif",
#                     "Nn": 0.0,
#                     "Of": 840.0,
#                     "Mul": 663.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0161219
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0031.tif",
#                     "Nn": 0.0,
#                     "Of": 899.0,
#                     "Mul": 718.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0153849
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0032.tif",
#                     "Nn": 0.0,
#                     "Of": 845.0,
#                     "Mul": 615.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.0134029
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0033.tif",
#                     "Nn": 0.0,
#                     "Of": 877.0,
#                     "Mul": 692.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.013304
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0034.tif",
#                     "Nn": 0.0,
#                     "Of": 842.0,
#                     "Mul": 423.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.012567
#                 },
#                 {
#                     "image": "OIS-Reech_CA214732V0035.tif",
#                     "Nn": 0.0,
#                     "Of": 602.0,
#                     "Mul": 268.0,
#                     "Mul-NN": 0.0,
#                     "Time": 0.00888705
#                 }
#             ],
#             "statistical_summary": {
#                 "PdsResNull": {
#                     "percentage": 4.18011,
#                     "number": 298
#                 },
#                 "Behind": {
#                     "percentage": 3.12807,
#                     "number": 223
#                 },
#                 "VisibIm": {
#                     "percentage": 92.6918,
#                     "number": 6608
#                 }
#             },
#             "epoch_stats": {}
#         },
#         {
#             "epoch": "3-3",
#             "image_processing": [],
#             "statistical_summary": {},
#             "epoch_stats": {}
#         }
#     ],
#     "warnings": {
#         "total_warnings": 0,
#         "types": []
#     }
# }
