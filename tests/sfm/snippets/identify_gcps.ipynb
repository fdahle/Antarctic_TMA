# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
image_ids = ["CA184632V0341", "CA184632V0342"]
transform_fld = "/data_1/ATM/data_1/georef/sat"

# %%
import src.load.load_image as li
import src.load.load_transform as lt

images = []
for image_id in image_ids:
    image = li.load_image(image_id)
    images.append(image)

transforms = []
for image_id in image_ids:
    transform = lt.load_transform(image_id + "_transform", transform_fld)
    transforms.append(transform)

# %%
import src.sfm.snippets.identify_gpcs as ig

points_dict = ig.identify_gcps(images, transforms)
print(points_dict)
# Out:
# 100%|██████████| 4137/4137 [00:45<00:00, 91.68it/s]
# {(-1924362.0, 752400.0): {'image_ids': [0, 1], 'rel_coords': [(8936, 331), (5322, 638)], 'avg_abs_coord': array([-1924362.,   752400.]), 'abs_coords': [(-1924366, 752403), (-1924358, 752397)]}, (-1924153.5, 752244.5): {'image_ids': [0, 1], 'rel_coords': [(9263, 410), (5619, 717)], 'avg_abs_coord': array([-1924153.5,   752244.5]), 'abs_coords': [(-1924154, 752245), (-1924153, 752244)]}, (-1924546.0, 752369.5): {'image_ids': [0, 1], 'rel_coords': [(8728, 460), (5114, 767)], 'avg_abs_coord': array([-1924546. ,   752369.5]), 'abs_coords': [(-1924546, 752372), (-1924546, 752367)]}, (-1925127.5, 752546.0): {'image_ids': [0, 1], 'rel_coords': [(7936, 549), (4371, 846)], 'avg_abs_coord': array([-1925127.5,   752546. ]), 'abs_coords': [(-1925131, 752548), (-1925124, 752544)]}, (-1924888.5, 752407.0): {'image_ids': [0, 1], 'rel_coords': [(8292, 589), (4698, 896)], 'avg_abs_coord': array([-1924888.5,   752407. ]), 'abs_coords': [(-1924888, 752410), (-1924889, 752404)]}, (-1925093.0, 752477.5): {'image_ids': [0, 1], 'rel_coords': [(8015, 608), (4430, 916)], 'avg_abs_coord': array([-1925093. ,   752477.5]), 'abs_coords': [(-1925090, 752481), (-1925096, 752474)]}, (-1924643.0, 752290.0): {'image_ids': [0, 1], 'rel_coords': [(8639, 608), (5034, 906)], 'avg_abs_coord': array([-1924643.,   752290.]), 'abs_coords': [(-1924647, 752290), (-1924639, 752290)]}, (-1927816.5, 753615.5): {'image_ids': [0, 1], 'rel_coords': [(4193, 648), (816, 925)], 'avg_abs_coord': array([-1927816.5,   753615.5]), 'abs_coords': [(-1927813, 753619), (-1927820, 753612)]}, (-1925341.5, 752537.5): {'image_ids': [0, 1], 'rel_coords': [(7688, 668), (4113, 965)], 'avg_abs_coord': array([-1925341.5,   752537.5]), 'abs_coords': [(-1925337, 752537), (-1925346, 752538)]}, (-1924035.0, 751932.0): {'image_ids': [0, 1], 'rel_coords': [(9540, 727), (5876, 1025)], 'avg_abs_coord': array([-1924035.,   751932.]), 'abs_coords': [(-1924037, 751928), (-1924033, 751936)]}, (-1924054.0, 751724.0): {'image_ids': [0, 1], 'rel_coords': [(9599, 975), (5935, 1292)], 'avg_abs_coord': array([-1924054.,   751724.]), 'abs_coords': [(-1924057, 751728), (-1924051, 751720)]}, (-1925283.5, 752138.5): {'image_ids': [0, 1], 'rel_coords': [(7916, 1114), (4341, 1411)], 'avg_abs_coord': array([-1925283.5,   752138.5]), 'abs_coords': [(-1925287, 752140), (-1925280, 752137)]}, (-1926508.0, 752568.0): {'image_ids': [0, 1], 'rel_coords': [(6233, 1233), (2747, 1510)], 'avg_abs_coord': array([-1926508.,   752568.]), 'abs_coords': [(-1926512, 752567), (-1926504, 752569)]}, (-1924361.0, 751571.5): {'image_ids': [0, 1], 'rel_coords': [(9292, 1322), (5628, 1619)], 'avg_abs_coord': array([-1924361. ,   751571.5]), 'abs_coords': [(-1924362, 751567), (-1924360, 751576)]}, (-1926621.5, 752362.5): {'image_ids': [0, 1], 'rel_coords': [(6183, 1530), (2687, 1817)], 'avg_abs_coord': array([-1926621.5,   752362.5]), 'abs_coords': [(-1926622, 752364), (-1926621, 752361)]}, (-1924402.0, 751385.5): {'image_ids': [0, 1], 'rel_coords': [(9322, 1560), (5648, 1867)], 'avg_abs_coord': array([-1924402. ,   751385.5]), 'abs_coords': [(-1924401, 751384), (-1924403, 751387)]}, (-1924451.5, 751310.5): {'image_ids': [0, 1], 'rel_coords': [(9292, 1669), (5619, 1986)], 'avg_abs_coord': array([-1924451.5,   751310.5]), 'abs_coords': [(-1924450, 751313), (-1924453, 751308)]}, (-1926633.0, 752064.5): {'image_ids': [0, 1], 'rel_coords': [(6292, 1896), (2787, 2174)], 'avg_abs_coord': array([-1926633. ,   752064.5]), 'abs_coords': [(-1926636, 752063), (-1926630, 752066)]}, (-1927857.0, 752535.0): {'image_ids': [0, 1], 'rel_coords': [(4599, 1956), (1172, 2233)], 'avg_abs_coord': array([-1927857.,   752535.]), 'abs_coords': [(-1927853, 752536), (-1927861, 752534)]}, (-1927955.5, 752523.0): {'image_ids': [0, 1], 'rel_coords': [(4480, 2025), (1064, 2293)], 'avg_abs_coord': array([-1927955.5,   752523. ]), 'abs_coords': [(-1927955, 752522), (-1927956, 752524)]}, (-1928078.0, 752504.0): {'image_ids': [0, 1], 'rel_coords': [(4341, 2105), (925, 2382)], 'av ...

# %%
import src.display.display_images as di

rel_po_0 = []
rel_po_1 = []

for key, value in points_dict.items():
    image_ids = value['image_ids']
    relative_positions = value['relative_positions']
    
    # Assuming image_ids always contain 0 and 1 in that order if they exist
    if 0 in image_ids:
        index_0 = image_ids.index(0)
        rel_po_0.append(relative_positions[index_0])
    
    if 1 in image_ids:
        index_1 = image_ids.index(1)
        rel_po_1.append(relative_positions[index_1])

di.display_images(images, points=[rel_po_0, rel_po_1])
# Out:
# [(8936, 331), (9263, 410), (8728, 460), (7936, 549), (8292, 589), (8015, 608), (8639, 608), (4193, 648), (7688, 668), (9540, 727), (9599, 975), (7916, 1114), (6233, 1233), (9292, 1322), (6183, 1530), (9322, 1560), (9292, 1669), (6292, 1896), (4599, 1956), (4480, 2025), (4341, 2105), (4727, 2154), (5718, 2154), (7173, 2164), (6114, 2223), (5827, 2273), (7688, 2600), (7163, 2610), (7787, 2610), (9282, 2679), (7718, 3204), (5797, 7346), (5658, 7415), (8362, 8277), (8104, 8337), (8470, 8347), (6114, 8377), (6609, 8763), (8946, 8872)]
